# %%
import pandas as pd

# %%
data = pd.read_csv('full-list-covid-19-tests-per-day.csv')

# %%
print(data.head())
# Out:
#     Entity Code         Day  new_tests 142602-annotations
# 0  Albania  ALB  2020-02-25          8    tests performed
# 1  Albania  ALB  2020-02-26          5    tests performed
# 2  Albania  ALB  2020-02-27          4    tests performed
# 3  Albania  ALB  2020-02-28          1    tests performed
# 4  Albania  ALB  2020-02-29          8    tests performed

# %%
data.plot

# %%
pd.plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-bac82cbd62a4> in <module>()
# ----> 1 pd.plot
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
pd.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-2c4694f4bb78> in <module>()
# ----> 1 pd.plot(x,y)
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
data.plot(x="Year", y="Technology Diffusion", kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6aac86eed70d> in <module>()
# ----> 1 data.plot(x="Year", y="Technology Diffusion", kind="line")
#
# NameError: name 'data' is not defined

# %%
plt.plot(x="Year", y="Technology Diffusion", kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1fd7804a359d> in <module>()
# ----> 1 plt.plot(x="Year", y="Technology Diffusion", kind="line")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
dataframe.plot(x="Year", y="Technology Diffusion", kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e91e31dc5642> in <module>()
# ----> 1 dataframe.plot(x="Year", y="Technology Diffusion", kind="line")
#
# NameError: name 'dataframe' is not defined

# %%
plt.plot(x="Year", y="Technology Diffusion", kind="line")
# Out:
# []

# %%
data = pd.read_csv('nba.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ed6081f5d8e5> in <module>()
# ----> 1 data = pd.read_csv('nba.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
data = pd.read_csv('nba.csv')

# %%
print(data.head())
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
dataframe.plot(x="Year", y="Technology Diffusion", kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e91e31dc5642> in <module>()
# ----> 1 dataframe.plot(x="Year", y="Technology Diffusion", kind="line")
#
# NameError: name 'dataframe' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x="Year", y="Technology Diffusion", kind="line")
# Out:
# []

# %%
plt.plot(x="Weight", y="Salary", kind ="line")
# Out:
# []

# %%
data.plot(x="Weight", y="Salary", kind ="line")
